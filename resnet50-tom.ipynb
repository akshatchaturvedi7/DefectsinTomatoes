# %%
import tensorflow as tf
import numpy as np 
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D , BatchNormalization , MaxPooling2D , Dense ,Flatten,  Dropout ,Activation 
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
IMG_HEIGHT = 227
IMG_WIDTH = 227
batch_size = 16
train_path = '../input/tomatoesforanalysis/dat/train'
test_path = '../input/tomatoesforanalysis/dat/test'
valid_path = '../input/tomatoesforanalysis/dat/val'

# %%
image_gen = ImageDataGenerator(
                                  rescale = 1./255,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True,          
                               )
test_data_gen = ImageDataGenerator(rescale = 1./255)

# %%
train = image_gen.flow_from_directory(
      train_path,
      target_size=(IMG_HEIGHT, IMG_WIDTH),
      color_mode='rgb',
      class_mode='binary',
      batch_size=batch_size
      )
test = test_data_gen.flow_from_directory(
      test_path,
      target_size=(IMG_HEIGHT, IMG_WIDTH),
      color_mode='rgb',
      shuffle=False, 
#setting shuffle as False just so we can later compare it with predicted values without having indexing problem 
      class_mode='binary',
      batch_size=batch_size
      )
valid = test_data_gen.flow_from_directory(
      valid_path,
      target_size=(IMG_HEIGHT, IMG_WIDTH),
      color_mode='rgb',
      class_mode='binary', 
      batch_size=batch_size
      )
# Out:
# Found 21921 images belonging to 2 classes.
# Found 10961 images belonging to 2 classes.
# Found 10961 images belonging to 2 classes.

# %%
plt.figure(figsize=(16, 16))
for i in range(0, 10):
    plt.subplot(2, 5, i+1)
    for X_batch, Y_batch in train:
        image = X_batch[0]        
        dic = {0:'DEFECTIVE', 1:'HEALTHY'}
        plt.title(dic.get(Y_batch[0]))
        plt.axis('off')
        plt.imshow(np.squeeze(image),cmap='gray',interpolation='nearest')
        break
plt.tight_layout()
plt.show()

# %%
# !pip install keras-metrics
# Out:
# Requirement already satisfied: keras-metrics in /opt/conda/lib/python3.7/site-packages (1.1.0)
# Requirement already satisfied: Keras>=2.1.5 in /opt/conda/lib/python3.7/site-packages (from keras-metrics) (2.4.3)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from Keras>=2.1.5->keras-metrics) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.7/site-packages (from Keras>=2.1.5->keras-metrics) (1.5.4)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from Keras>=2.1.5->keras-metrics) (5.3.1)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from Keras>=2.1.5->keras-metrics) (1.19.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py->Keras>=2.1.5->keras-metrics) (1.15.0)

# %%
import keras
import keras_metrics as km
from tensorflow.keras.callbacks import Callback
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import recall_score, precision_score, f1_score
from keras.layers import Dense, GlobalAveragePooling2D

#Define model
model=tf.keras.applications.ResNet50(
            input_shape=(IMG_HEIGHT,IMG_WIDTH,3),
            weights='imagenet',
            include_top=False,
        )
#model.trainable = False
#Output layer
x = model.output
x = GlobalAveragePooling2D()(x)
x = Dense(64, activation="relu")(x)
x = Dense(32, activation="relu")(x)
predictions = Dense(1, activation="sigmoid")(x)


#Compile model
model=Model(inputs=model.input,outputs=predictions)
precision = km.binary_precision(label=1)
recall = km.binary_recall(label=0)

model.compile(optimizer='adam',
              loss='binary_crossentropy', 
              metrics=['accuracy',precision,recall])

model_history = model.fit(train,
                            validation_data=valid,
                            steps_per_epoch=train.n/batch_size,
                            validation_steps=valid.n/batch_size,
                            epochs=20,
                            verbose=1,
                            callbacks=[ModelCheckpoint('model.hdf5', 
                                        save_best_only=True, 
                                        verbose=0, 
                                        monitor='val_loss', 
                                        mode='min'), 
                                       ReduceLROnPlateau(monitor='val_loss', 
                                        factor=0.3, 
                                        patience=3, 
                                        min_lr=0.0001, 
                                        verbose=1)])
# Out:
# Epoch 1/20
# 1370/1370 [==============================] - 327s 234ms/step - loss: 0.3017 - accuracy: 0.8914 - precision: 0.0000e+00 - recall: 0.9826 - val_loss: 0.1958 - val_accuracy: 0.9246 - val_precision: 0.0000e+00 - val_recall: 0.9935
# Epoch 2/20
# 1370/1370 [==============================] - 313s 228ms/step - loss: 0.1789 - accuracy: 0.9385 - precision: 0.0000e+00 - recall: 0.9813 - val_loss: 0.1722 - val_accuracy: 0.9463 - val_precision: 0.0000e+00 - val_recall: 0.9962
# Epoch 3/20
# 1370/1370 [==============================] - 317s 231ms/step - loss: 0.1646 - accuracy: 0.9432 - precision: 0.0000e+00 - recall: 0.9831 - val_loss: 0.3489 - val_accuracy: 0.9406 - val_precision: 0.0000e+00 - val_recall: 0.9995
# Epoch 4/20
# 1370/1370 [==============================] - 319s 233ms/step - loss: 0.1417 - accuracy: 0.9510 - precision: 0.0000e+00 - recall: 0.9873 - val_loss: 0.1759 - val_accuracy: 0.9417 - val_precision: 0.0000e+00 - val_recall: 0.9687
# Epoch 5/20
# 1370/1370 [==============================] - 309s 225ms/step - loss: 0.1416 - accuracy: 0.9515 - precision: 0.0000e+00 - recall: 0.9866 - val_loss: 0.1854 - val_accuracy: 0.9411 - val_precision: 0.0000e+00 - val_recall: 0.9988
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 6/20
# 1370/1370 [==============================] - 308s 224ms/step - loss: 0.1058 - accuracy: 0.9631 - precision: 0.0000e+00 - recall: 0.9879 - val_loss: 0.0944 - val_accuracy: 0.9703 - val_precision: 0.0000e+00 - val_recall: 0.9941
# Epoch 7/20
# 1370/1370 [==============================] - 308s 225ms/step - loss: 0.0979 - accuracy: 0.9681 - precision: 0.0000e+00 - recall: 0.9887 - val_loss: 0.1116 - val_accuracy: 0.9643 - val_precision: 0.0000e+00 - val_recall: 0.9798
# Epoch 8/20
# 1370/1370 [==============================] - 308s 225ms/step - loss: 0.0933 - accuracy: 0.9706 - precision: 0.0000e+00 - recall: 0.9917 - val_loss: 0.0927 - val_accuracy: 0.9719 - val_precision: 0.0000e+00 - val_recall: 0.9930
# Epoch 9/20
# 1370/1370 [==============================] - 296s 216ms/step - loss: 0.0917 - accuracy: 0.9716 - precision: 0.0000e+00 - recall: 0.9919 - val_loss: 0.0873 - val_accuracy: 0.9728 - val_precision: 0.0000e+00 - val_recall: 0.9949
# Epoch 10/20
# 1370/1370 [==============================] - 290s 212ms/step - loss: 0.0945 - accuracy: 0.9697 - precision: 0.0000e+00 - recall: 0.9890 - val_loss: 0.1037 - val_accuracy: 0.9677 - val_precision: 0.0000e+00 - val_recall: 0.9978
# Epoch 11/20
# 1370/1370 [==============================] - 291s 213ms/step - loss: 0.0874 - accuracy: 0.9706 - precision: 0.0000e+00 - recall: 0.9909 - val_loss: 0.0872 - val_accuracy: 0.9701 - val_precision: 0.0000e+00 - val_recall: 0.9844
# Epoch 12/20
# 1370/1370 [==============================] - 292s 213ms/step - loss: 0.0820 - accuracy: 0.9730 - precision: 0.0000e+00 - recall: 0.9905 - val_loss: 0.1166 - val_accuracy: 0.9577 - val_precision: 0.0000e+00 - val_recall: 0.9677
# Epoch 13/20
# 1370/1370 [==============================] - 293s 213ms/step - loss: 0.0845 - accuracy: 0.9724 - precision: 0.0000e+00 - recall: 0.9896 - val_loss: 0.1002 - val_accuracy: 0.9690 - val_precision: 0.0000e+00 - val_recall: 0.9957
# Epoch 14/20
# 1370/1370 [==============================] - 293s 214ms/step - loss: 0.0866 - accuracy: 0.9726 - precision: 0.0000e+00 - recall: 0.9930 - val_loss: 0.0954 - val_accuracy: 0.9707 - val_precision: 0.0000e+00 - val_recall: 0.9943
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 15/20
# 1370/1370 [==============================] - 294s 214ms/step - loss: 0.0781 - accuracy: 0.9744 - precision: 0.0000e+00 - recall: 0.9940 - val_loss: 0.0795 - val_accuracy: 0.9765 - val_precision: 0.0000e+00 - val_recall: 0.9915
# Epoch 16/20
# 1370/1370 [==============================] - 294s 214ms/step - loss: 0.0707 - accuracy: 0.9771 - precision: 0.0000e+00 - recall: 0.9926 - val_loss: 0.0805 - val_accuracy: 0.9734 - val_precision: 0.0000e+00 - val_recall: 0.9864
# Epoch 17/20
# 1370/1370 [==============================] - 296s 216ms/step - loss: 0.0698 - accuracy: 0.9769 - precision: 0.0000e+00 - recall: 0.9911 - val_loss: 0.0842 - val_accuracy: 0.9743 - val_precision: 0.0000e+00 - val_recall: 0.9970
# Epoch 18/20
# 1370/1370 [==============================] - 299s 218ms/step - loss: 0.0677 - accuracy: 0.9781 - precision: 0.0000e+00 - recall: 0.9945 - val_loss: 0.0778 - val_accuracy: 0.9757 - val_precision: 0.0000e+00 - val_recall: 0.9928
# Epoch 19/20
# 1370/1370 [==============================] - 296s 216ms/step - loss: 0.0686 - accuracy: 0.9775 - precision: 0.0000e+00 - recall: 0.9917 - val_loss: 0.0800 - val_accuracy: 0.9757 - val_precision: 0.0000e+00 - val_recall: 0.9938
# Epoch 20/20
# 1370/1370 [==============================] - 294s 215ms/step - loss: 0.0703 - accuracy: 0.9766 - precision: 0.0000e+00 - recall: 0.9918 - val_loss: 0.0814 - val_accuracy: 0.9745 - val_precision: 0.0000e+00 - val_recall: 0.9912

# %%
model.load_weights("model.hdf5")

# %%
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']

epochs = range(len(acc))
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

# %%
loss=model_history.history['loss']
val_loss=model_history.history['val_loss']

epochs=range(len(loss))
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()

# %%
preds = model.predict_generator(generator=test) # get proba predictions
labels = 1*(preds > 0.5) # convert proba to classes
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
CM = confusion_matrix(test.classes, labels)
fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(5, 5))
plt_labels = ['DEFECTIVE','HEALTHY']
ax.set_xticklabels([''] + plt_labels)
ax.set_yticklabels([''] + plt_labels)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   import sys

# %%
from sklearn.metrics import classification_report
print(classification_report(test.classes, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.85      0.89      1240
#            1       0.98      0.99      0.99      9721
#
#     accuracy                           0.98     10961
#    macro avg       0.96      0.92      0.94     10961
# weighted avg       0.98      0.98      0.98     10961
